# %%
import numpy as np
import pandas as pd
import requests

# %%
response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page=1')

# %%
response.json()['results']
# Out:
# [{'adult': False,
#   'backdrop_path': '/tmU7GeKVybMWFButWEGl2M4GeiP.jpg',
#   'genre_ids': [18, 80],
#   'id': 238,
#   'original_language': 'en',
#   'original_title': 'The Godfather',
#   'overview': 'Spanning the years 1945 to 1955, a chronicle of the fictional Italian-American Corleone crime family. When organized crime family patriarch, Vito Corleone barely survives an attempt on his life, his youngest son, Michael steps in to take care of the would-be killers, launching a campaign of bloody revenge.',
#   'popularity': 129.844,
#   'poster_path': '/3bhkrj58Vtu7enYsRolD1fZdja1.jpg',
#   'release_date': '1972-03-14',
#   'title': 'The Godfather',
#   'video': False,
#   'vote_average': 8.7,
#   'vote_count': 18502},
#  {'adult': False,
#   'backdrop_path': '/kXfqcdQKsToO0OUXHcrrNCHDBzO.jpg',
#   'genre_ids': [18, 80],
#   'id': 278,
#   'original_language': 'en',
#   'original_title': 'The Shawshank Redemption',
# ...

# %%
# we extract only this col
# id  , overview ,poster_path , popularity,release_date,title,vote_average,original_language

# %%
df = pd.DataFrame()

# %%
for i in range(1 , 572):  # total pages 571
    
    response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page={}'.format(i))
    
    temp_df = pd.DataFrame(response.json()['results'])[['id', 'title', 'overview','poster_path','popularity' , 'release_date','vote_average','original_language','vote_count']]

    df = df.append(temp_df , ignore_index=True)
# Out:
# C:\Users\Satya\AppData\Local\Temp\ipykernel_3480\3761032749.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df , ignore_index=True)
# C:\Users\Satya\AppData\Local\Temp\ipykernel_3480\3761032749.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df , ignore_index=True)
# C:\Users\Satya\AppData\Local\Temp\ipykernel_3480\3761032749.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df , ignore_index=True)
# C:\Users\Satya\AppData\Local\Temp\ipykernel_3480\3761032749.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df , ignore_index=True)
# ...

# %%
df.shape
# Out:
# (10000, 11)

# %%
df.head()
# Out:
#       id                        title  \
# 0    238                The Godfather
# 1    278     The Shawshank Redemption
# 2    240        The Godfather Part II
# 3    424             Schindler's List
# 4  19404  Dilwale Dulhania Le Jayenge
#
#                                             overview  \
# 0  Spanning the years 1945 to 1955, a chronicle o...
# 1  Framed in the 1940s for the double murder of h...
# 2  In the continuing saga of the Corleone crime f...
# 3  The true story of how businessman Oskar Schind...
# 4  Raj is a rich, carefree, happy-go-lucky second...
#
#                         poster_path  popularity release_date  vote_average  \
# 0  /3bhkrj58Vtu7enYsRolD1fZdja1.jpg     129.844   1972-03-14           8.7
# 1  /lyQBXzOQSuE59IsHyhrp0qIiPAz.jpg     134.708   1994-09-23           8.7
# 2  /bMadFzhjy9T7R8J48QGq1ngWNAK.jpg      75.052   1974-12-20           8.6
# 3  /sF1U4EUQS8YHUYjNl3pMGNIQyr0.jpg      60.787   1993-12-15           8.6
# ...

# %%
# now we'll fetch movies genres based on movies id

# %%
genres_dict = {'genres':[] , "id":[]}

# %%
def fetch_genres(ids_range):
    for i in ids_range:
        data = requests.get('https://api.themoviedb.org/3/movie/{}?api_key=d9db7dd8c18e08fcd352c806889dd09e&language=en-US'.format(i))
        data = data.json()
        genres_dict['genres'].append(data['genres'])
        genres_dict['id'].append(i)
    
    return genres_dict

# %%
# 1st 5000 movies genres
genres_dict_1 = fetch_genres(list(df['id'])[:5000])

# %%
len(genres_dict['id'])
# Out:
# 5000

# %%
# 2nd 5000 movies genres
genres_dict_2 = fetch_genres(list(df['id'])[5000:10000])

# %%
len(genres_dict_2['id'])  #total 10K
# Out:
# 10000

# %%
genres_df = pd.DataFrame(genres_dict_2)
genres_df.shape
# Out:
# (10000, 2)

# %%
genres_df.head()
# Out:
#                                               genres     id
# 0  [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name...    238
# 1  [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name...    278
# 2  [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name...    240
# 3  [{'id': 18, 'name': 'Drama'}, {'id': 36, 'name...    424
# 4  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...  19404

# %%
# unique id
genres_df['id'].nunique()
# Out:
# 10000

# %%
# save movies and genres inot csv

df.to_csv('movies_new.csv')

# %%
genres_df.to_csv('genres.csv')

# %%
# now we'll fetch cast and crew

# %%
url = 'https://api.themoviedb.org/3/movie/19995/credits?api_key=d9db7dd8c18e08fcd352c806889dd09e&language=en-US'

# %%
data = requests.get('https://api.themoviedb.org/3/movie/19995/credits?api_key=d9db7dd8c18e08fcd352c806889dd09e&language=en-US')
data = data.json()

# %%
data
# Out:
# {'id': 19995,
#  'cast': [{'adult': False,
#    'gender': 2,
#    'id': 65731,
#    'known_for_department': 'Acting',
#    'name': 'Sam Worthington',
#    'original_name': 'Sam Worthington',
#    'popularity': 37.593,
#    'profile_path': '/mflBcox36s9ZPbsZPVOuhf6axaJ.jpg',
#    'cast_id': 242,
#    'character': 'Jake Sully',
#    'credit_id': '5602a8a7c3a3685532001c9a',
#    'order': 0},
#   {'adult': False,
#    'gender': 1,
#    'id': 8691,
#    'known_for_department': 'Acting',
#    'name': 'Zoe Saldaña',
#    'original_name': 'Zoe Saldaña',
#    'popularity': 86.493,
#    'profile_path': '/iOVbUH20il632nj2v01NCtYYeSg.jpg',
#    'cast_id': 3,
#    'character': 'Neytiri',
#    'credit_id': '52fe48009251416c750ac9cb',
#    'order': 1},
#   {'adult': False,
#    'gender': 2,
#    'id': 32747,
#    'known_for_department': 'Acting',
#    'name': 'Stephen Lang',
#    'original_name': 'Stephen Lang',
#    'popularity': 36.842,
#    'profile_path': '/xEBuFWrCKDQD6r6CZK71GYIc4UW.jpg',
# ...

# %%
credits = {"id":[] , 'cast':[] , 'crew':[]}

# %%
for i in list(df['id']):
    
    data = requests.get('https://api.themoviedb.org/3/movie/{}/credits?api_key=d9db7dd8c18e08fcd352c806889dd09e&language=en-US'.format(i))
    data = data.json()
    credits['id'].append(data['id'])
    credits['cast'].append(data['cast'])
    credits['crew'].append(data['crew'])

# %%
credits_df = pd.DataFrame(credits)

# %%
credits_df.head()
# Out:
#       id                                               cast  \
# 0    238  [{'adult': False, 'gender': 2, 'id': 3084, 'kn...
# 1    278  [{'adult': False, 'gender': 2, 'id': 504, 'kno...
# 2    240  [{'adult': False, 'gender': 2, 'id': 1158, 'kn...
# 3    424  [{'adult': False, 'gender': 2, 'id': 3896, 'kn...
# 4  19404  [{'adult': False, 'gender': 2, 'id': 35742, 'k...
#
#                                                 crew
# 0  [{'adult': False, 'gender': 2, 'id': 154, 'kno...
# 1  [{'adult': False, 'gender': 2, 'id': 153, 'kno...
# 2  [{'adult': False, 'gender': 2, 'id': 154, 'kno...
# 3  [{'adult': False, 'gender': 2, 'id': 491, 'kno...
# 4  [{'adult': False, 'gender': 1, 'id': 8311, 'kn...

# %%
credits_df.shape
# Out:
# (10000, 3)

# %%
credits_df.to_csv('credits.csv')

# %%
import pandas as pd
import numpy as np
import requests

# %%
df = pd.read_csv('movies.csv')

# %%
# now fetch movies keywords

# %%
data = requests.get('https://api.themoviedb.org/3/movie/19995/keywords?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US')
data = data.json()

# %%
data['keywords']
# Out:
# [{'id': 1463, 'name': 'culture clash'},
#  {'id': 2964, 'name': 'future'},
#  {'id': 3386, 'name': 'space war'},
#  {'id': 3388, 'name': 'space colony'},
#  {'id': 3679, 'name': 'society'},
#  {'id': 3801, 'name': 'space travel'},
#  {'id': 9685, 'name': 'futuristic'},
#  {'id': 9840, 'name': 'romance'},
#  {'id': 9882, 'name': 'space'},
#  {'id': 9951, 'name': 'alien'},
#  {'id': 10148, 'name': 'tribe'},
#  {'id': 10158, 'name': 'alien planet'},
#  {'id': 11399, 'name': 'marine'},
#  {'id': 13065, 'name': 'soldier'},
#  {'id': 14643, 'name': 'battle'},
#  {'id': 14720, 'name': 'love affair'},
#  {'id': 18330, 'name': 'nature'},
#  {'id': 165431, 'name': 'anti war'},
#  {'id': 193554, 'name': 'power relations'},
#  {'id': 206690, 'name': 'mind and soul'}]

# %%
keywords = {"id":[] , "keywords":[]}

# %%
for i in list(df['id']):
    data = requests.get('https://api.themoviedb.org/3/movie/{}/keywords?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US'.format(i))
    data = data.json()
    keywords['id'].append(data['id'])
    keywords['keywords'].append(data['keywords'])

# %%
keywords_df = pd.DataFrame(keywords)

# %%
keywords_df.to_csv('keywords.csv')
